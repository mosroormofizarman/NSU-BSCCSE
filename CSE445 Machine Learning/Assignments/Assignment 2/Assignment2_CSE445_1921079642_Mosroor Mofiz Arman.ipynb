# %%
# Load libraries
import pandas as pd
import graphviz
import pydotplus
from sklearn.tree import DecisionTreeClassifier
#from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.tree import export_graphviz
from six import StringIO
from IPython.display import Image

# %%
# Mount the Google Drive into Colab to use the drive files
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# The location of the csv file in Google Drive
csv_location = './drive/MyDrive/Assignment2Data.csv'

# %%
# load dataset
df = pd.read_csv(csv_location)
df.head(7)
# Out:
#   High Colesterol Regular Exercise  Age  Diabetes
# 0               Y                Y    7         0
# 1               Y                N   18         0
# 2               N                Y   12         1
# 3               N                Y   38         1
# 4               Y                Y   35         1
# 5               Y                N   50         0
# 6               N                N   83         0

# %%
#split dataset in features and target variable
feature_cols = ['High Colesterol', 'Regular Exercise', 'Age']
X = df[feature_cols] # Features
y = df.Diabetes # Target variable

# %%
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1) # 70% training and 30% test

# %%
# Create an instance of OneHotEncoder with handle_unknown='ignore'
encoder = OneHotEncoder(handle_unknown='ignore')

# Fit and transform the training features
X_train_encoded = encoder.fit_transform(X_train)

# Transform the test features
X_test_encoded = encoder.transform(X_test)

# Create Decision Tree classifier object
clf = DecisionTreeClassifier()

# Train Decision Tree Classifier
clf = clf.fit(X_train_encoded, y_train)

# Predict the response for test dataset
y_pred = clf.predict(X_test_encoded)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.6666666666666666

# %%
# Shows a visualization of the decision tree using graphviz
dot_data = StringIO()
export_graphviz(clf, out_file=dot_data,
                filled=True, rounded=True,
                special_characters=True,feature_names = feature_cols,class_names=['0','1'])

graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
Image(graph.create_png())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-4a7195a5df0c> in <cell line: 3>()
#       1 # Shows a visualization of the decision tree using graphviz
#       2 dot_data = StringIO()
# ----> 3 export_graphviz(clf, out_file=dot_data,
#       4                 filled=True, rounded=True,
#       5                 special_characters=True,feature_names = feature_cols,class_names=['0','1'])
#
# /usr/local/lib/python3.10/dist-packages/sklearn/tree/_export.py in export_graphviz(decision_tree, out_file, max_depth, feature_names, class_names, label, filled, leaves_parallel, impurity, node_ids, proportion, rotate, rounded, special_characters, precision, fontname)
#     886             fontname=fontname,
#     887         )
# --> 888         exporter.export(decision_tree)
#     889
#     890         if return_string:
#
# /usr/local/lib/python3.10/dist-packages/sklearn/tree/_export.py in export(self, decision_tree)
#     449         if self.feature_names is not None:
#     450             if len(self.feature_names) != decision_tree.n_features_in_:
# --> 451                 raise ValueError(
#     452                     "Length of feature_names, %d does not match number of features, %d"
#     453                     % (len(self.feature_names), decision_tree.n_features_in_)
#
# ValueError: Length of feature_names, 3 does not match number of features, 8
